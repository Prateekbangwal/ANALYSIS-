# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

# %%
deliveries_data = pd.read_csv('deliveries.csv')
matches_data = pd.read_csv('matches.csv')

# %%
print(matches_data)
# Out:
#       id  season           city        date                        team1  \
# 0      1    2017      Hyderabad  2017-04-05          Sunrisers Hyderabad
# 1      2    2017           Pune  2017-04-06               Mumbai Indians
# 2      3    2017         Rajkot  2017-04-07                Gujarat Lions
# 3      4    2017         Indore  2017-04-08       Rising Pune Supergiant
# 4      5    2017      Bangalore  2017-04-08  Royal Challengers Bangalore
# 5      6    2017      Hyderabad  2017-04-09                Gujarat Lions
# 6      7    2017         Mumbai  2017-04-09        Kolkata Knight Riders
# 7      8    2017         Indore  2017-04-10  Royal Challengers Bangalore
# 8      9    2017           Pune  2017-04-11             Delhi Daredevils
# 9     10    2017         Mumbai  2017-04-12          Sunrisers Hyderabad
# 10    11    2017        Kolkata  2017-04-13              Kings XI Punjab
# 11    12    2017      Bangalore  2017-04-14  Royal Challengers Bangalore
# ...

# %%
print(deliveries_data)
# Out:
#         match_id  inning                 batting_team  \
# 0              1       1          Sunrisers Hyderabad
# 1              1       1          Sunrisers Hyderabad
# 2              1       1          Sunrisers Hyderabad
# 3              1       1          Sunrisers Hyderabad
# 4              1       1          Sunrisers Hyderabad
# 5              1       1          Sunrisers Hyderabad
# 6              1       1          Sunrisers Hyderabad
# 7              1       1          Sunrisers Hyderabad
# 8              1       1          Sunrisers Hyderabad
# 9              1       1          Sunrisers Hyderabad
# 10             1       1          Sunrisers Hyderabad
# 11             1       1          Sunrisers Hyderabad
# 12             1       1          Sunrisers Hyderabad
# 13             1       1          Sunrisers Hyderabad
# 14             1       1          Sunrisers Hyderabad
# 15             1       1          Sunrisers Hyderabad
# ...

# %%
print(matches_data.shape)
print(deliveries_data.shape)
# Out:
# (636, 18)
# (150460, 21)

# %%
matches_data.head()
# Out:
#    id  season       city        date                        team1  \
# 0   1    2017  Hyderabad  2017-04-05          Sunrisers Hyderabad
# 1   2    2017       Pune  2017-04-06               Mumbai Indians
# 2   3    2017     Rajkot  2017-04-07                Gujarat Lions
# 3   4    2017     Indore  2017-04-08       Rising Pune Supergiant
# 4   5    2017  Bangalore  2017-04-08  Royal Challengers Bangalore
#
#                          team2                  toss_winner toss_decision  \
# 0  Royal Challengers Bangalore  Royal Challengers Bangalore         field
# 1       Rising Pune Supergiant       Rising Pune Supergiant         field
# 2        Kolkata Knight Riders        Kolkata Knight Riders         field
# 3              Kings XI Punjab              Kings XI Punjab         field
# 4             Delhi Daredevils  Royal Challengers Bangalore           bat
#
#    result  dl_applied                       winner  win_by_runs  \
# ...

# %%
a = matches_data.loc[matches_data['dl_applied']==1]
print(a)
# Out:
#       id  season           city        date                        team1  \
# 56    57    2017      Bangalore  2017-05-17          Sunrisers Hyderabad
# 99   100    2008          Delhi  2008-05-17             Delhi Daredevils
# 102  103    2008        Kolkata  2008-05-18        Kolkata Knight Riders
# 119  120    2009      Cape Town  2009-04-19              Kings XI Punjab
# 122  123    2009         Durban  2009-04-21              Kings XI Punjab
# 148  149    2009      Centurion  2009-05-07          Chennai Super Kings
# 251  252    2011          Kochi  2011-04-18          Chennai Super Kings
# 280  281    2011        Kolkata  2011-05-07          Chennai Super Kings
# 290  291    2011      Bangalore  2011-05-14        Kolkata Knight Riders
# 488  489    2014          Delhi  2014-05-10             Delhi Daredevils
# 536  537    2015  Visakhapatnam  2015-04-22          Sunrisers Hyderabad
# 567  568    2015      Hyderabad  2015-05-15          Sunrisers Hyderabad
# ...

# %%
a = matches_data.loc[matches_data['dl_applied']==1]
print(a)
# Out:
#       id  season           city        date                        team1  \
# 56    57    2017      Bangalore  2017-05-17          Sunrisers Hyderabad
# 99   100    2008          Delhi  2008-05-17             Delhi Daredevils
# 102  103    2008        Kolkata  2008-05-18        Kolkata Knight Riders
# 119  120    2009      Cape Town  2009-04-19              Kings XI Punjab
# 122  123    2009         Durban  2009-04-21              Kings XI Punjab
# 148  149    2009      Centurion  2009-05-07          Chennai Super Kings
# 251  252    2011          Kochi  2011-04-18          Chennai Super Kings
# 280  281    2011        Kolkata  2011-05-07          Chennai Super Kings
# 290  291    2011      Bangalore  2011-05-14        Kolkata Knight Riders
# 488  489    2014          Delhi  2014-05-10             Delhi Daredevils
# 536  537    2015  Visakhapatnam  2015-04-22          Sunrisers Hyderabad
# 567  568    2015      Hyderabad  2015-05-15          Sunrisers Hyderabad
# ...

# %%
len(a)
# Out:
# 16

# %% [markdown]
# Biggest run margin victory match info

# %%
matches_data[matches_data['win_by_runs'] == matches_data['win_by_runs'].max()]
# Out:
#     id  season   city        date           team1             team2  \
# 43  44    2017  Delhi  2017-05-06  Mumbai Indians  Delhi Daredevils
#
#          toss_winner toss_decision  result  dl_applied          winner  \
# 43  Delhi Daredevils         field  normal           0  Mumbai Indians
#
#     win_by_runs  win_by_wickets player_of_match             venue  \
# 43          146               0     LMP Simmons  Feroz Shah Kotla
#
#         umpire1    umpire2  umpire3
# 43  Nitin Menon  CK Nandan      NaN

# %% [markdown]
# From 2008 to 2017 tied IPL Matches

# %%
(matches_data.loc[matches_data['result']=='tie'])
# Out:
#       id  season       city        date                        team1  \
# 33    34    2017     Rajkot  2017-04-29                Gujarat Lions
# 125  126    2009  Cape Town  2009-04-23             Rajasthan Royals
# 189  190    2010    Chennai  2010-03-21              Kings XI Punjab
# 387  388    2013  Hyderabad  2013-04-07  Royal Challengers Bangalore
# 400  401    2013  Bangalore  2013-04-16             Delhi Daredevils
# 475  476    2014  Abu Dhabi  2014-04-29             Rajasthan Royals
# 535  536    2015  Ahmedabad  2015-04-21             Rajasthan Royals
#
#                            team2                  toss_winner toss_decision  \
# 33                Mumbai Indians                Gujarat Lions           bat
# 125        Kolkata Knight Riders        Kolkata Knight Riders         field
# 189          Chennai Super Kings          Chennai Super Kings         field
# 387          Sunrisers Hyderabad  Royal Challengers Bangalore           bat
# ...

# %%
len(matches_data.loc[matches_data['result']=='tie'])
# Out:
# 7

# %% [markdown]
# Highest number of matches played at a venue

# %%
matches_data["venue"].value_counts().nlargest(n=1).values[0]
# Out:
# 66

# %%
matches_data['venue'].mode()
# Out:
# 0    M Chinnaswamy Stadium
# dtype: object

# %% [markdown]
# At which venue maximum times D.l Applied

# %%
a['venue'].mode()
# Out:
# 0             Eden Gardens
# 1    M Chinnaswamy Stadium
# dtype: object

# %%
a['venue'].value_counts().nlargest(n=1).values[0]
# Out:
# 3

# %% [markdown]
# 7 Most Played venue in the History of IPL from 2008 to 2017

# %%
sns.set_style("darkgrid")
ls = matches_data['venue'].value_counts().sort_values(ascending=False)
ls=ls[:7]
plt.figure(figsize=(20,6))
Most_Played =sns.barplot(ls.index, ls.values, alpha = 0.8)
plt.title('Most Played venue')
plt.ylabel('Count', fontsize=12)
plt.xlabel('Name of the stadiums', fontsize=10)
Most_Played.set_xticklabels(rotation=30,labels=ls.index,fontsize=10)
plt.show()
